# %% [markdown]
# # U-NET modified for density kernel estimation
#
#
# U-NET is a popular end-to-end segmentation net used in biomedical imaging [1]. Following a suggestion from a friend (Weidi Xie) I wanted to see if this network structure could be used to perform density estimation. I took the U-NET implementation from Weidi. With some small changes and some basic pre-processing I have been able to achieve close to state-of-the-art performance.
#
# #### Background:
#
# By using machine learning it is possible to learn a mapping from intensity to a density kernel representation of cells and objects. Through integration of the densities one can then predict the number of cells of objects in a scene without having to explicity segment the objects of interest. [2] To do this accurately, for typical images, it is necessary to characterise the image pixels by calculating long feature descriptors which can abstract image information in different ways and at different scales. Neural networks can handle large training sets and learn features which are tuned for specific applications. Many different networks can be applied to this problem however the current state-of-the-art for density kernel estimation in 2-D is a Fully Convolutional Regression Neural Network [3] which comprises of convolutional layers along with the normal activation and pooling layers, but then has upsampling layers which allow the output of the network to expand to be in parity with the input dimension. U-NET is a fully convolutional network also but it uses concatenations of layers and a highly symmetrical network design. I was interested to see if this could be directly applied to the density estimation and how well it would peform.
#
# #### Changes:
#
# -- The loss function used is 'mse' not 'cross-entropy'.
#
# -- As I am not performing segmentation so don't use softmax and use relu rather than sigmoid in the last activation layer.
#
# -- As mentioned in [2] it is important to scale the density kernels from 0.0-1.0 to something higher ( in this case 0.0-255.0) otherwise the network struggles to learn the very small target values produced by Gaussian convolution. These values are down-scaled subsequently to valid densities (0.0-1.0).
#
# #### Datasets:
#
# I used one some of a dataset which I have recieved from a collaborator (Caroline Scott). These are cells imaged using bright-field microscopy. We are interested in how many cells are present in each image.
#
#
# #### Bibliography:
#
# [1] Ronneberger, Olaf, Philipp Fischer, and Thomas Brox. "U-net: Convolutional networks for biomedical image segmentation." International Conference on Medical Image Computing and Computer-Assisted Intervention. Springer International Publishing, 2015.
#
# [2] Lempitsky, Victor, and Andrew Zisserman. "Learning to count objects in images." Advances in Neural Information Processing Systems. 2010.
#
# [3] Xie, Weidi, J. Alison Noble, and Andrew Zisserman. "Microscopy Cell Counting with Fully Convolutional Regression Networks."

# %%
# %pylab inline

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0" #Ensures I only use one of my available GPUs.
from random import Random
import cPickle as pickle


import tensorflow as tf
import keras
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.backend.tensorflow_backend import set_session
from keras.models import Sequential, Model, load_model


config = tf.ConfigProto()
#Uses 80% of the memory of one GPU, rather than all the memory of all the GPUs
config.gpu_options.per_process_gpu_memory_fraction = 0.8 
set_session(tf.Session(config=config))


#Some other specialist functions which could easily be substituted.
from PIL import Image #for image import and output
from scipy import ndimage #for Gaussian filtering
import cv2 #for padding function of image border.
from sklearn.model_selection import train_test_split

from model import buildModel #additional functions
from generator import ImageDataGenerator, split_the_images #additional functions



class TestCallback(Callback):
    """This function reports back the progress of the learning."""
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
    def on_train_begin(self, logs={}):
        self.losses = []
        
def step_decay(epoch):
    """This sets up the various decays of the learning rate."""
    step = 16
    num =  epoch // step
   
    if num >2:
         lrate = 1e-6
    else:
        if num % 3 == 0:
            lrate = 1e-3
        elif num % 3 == 1:
            lrate = 1e-4
        elif num % 3:
            lrate = 1e-5
    print('Learning rate for epoch {} is {}.'.format(epoch+1, lrate))
    return np.float(lrate)

def dice_coef(y_true, y_pred):
    """This is the default U-NET loss function which I do not use."""
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    smooth =1.0
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def get_unet(img_rows,img_cols):
    return buildModel(input_dim = (img_rows,img_cols,1))

def return_shuffled_im(train_size, test_size, input_seq):
    """returns shuffled indices for test and training data."""
    input_seq = input_seq.astype(np.int32)
    image_pool_size = np.array(input_seq).shape
    rand_seq = np.random.choice(input_seq,input_seq.shape[0],replace=True)

    assert (train_size + test_size) <= image_pool_size,\
    'your combined test and train images exceeds the number of images in your input sequence.'

    shuf_train_images = rand_seq[:train_size]
    shuf_test_images = rand_seq[train_size:train_size+test_size]


    return shuf_train_images, shuf_test_images
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Code for training algorithm

# %%
#generate how many models.
models_to_gen = 5

for bt in range(0,models_to_gen):
    
    file_path = 'dataset02/' #Dataset to use.
    data_store = {}
    data_store['input'] = []
    data_store['gt'] = []
    data_store['dense'] = []
    
    #Parameters of fit.
    in_hei = 96 #Size of each image patch
    in_wid = 96 #Size of each image patch
    mag = 16 #The padding margin to use
    train_size = 62 #The number of training images.
    test_size = 18 #The number of test images.
    learning_rate ="1e-5 see learning rate decay"
    batch_size = 16 #For stochastic gradient descent, the number of images in each batch.
    nb_epoch = 100 #The number of epochs
    samples_per_epoch = 150 #For stochastic gradient descent, the number of batches per epoch.
    image_pool_size = train_size+test_size
    input_seq = np.arange(0,image_pool_size)
    sigma = 2.0 #Size of kernel representing the ground-truth density.
    save_best_only = False
    loss = 'mse' #I use mean square error in this case.
   
    decay = 0.0
    
    
    #Experiment number should match filename
    filepath="saved_models/keras_tf_exp_sdataset02s2_model_"+str(bt)
    
    for i in range(0,image_pool_size):
        n = str(i+1).zfill(3)
        
        #Open intensity image.
        img = Image.open(file_path+n+'cells.png').getdata()
        wid, hei = img.size
        temp = np.array(img).reshape((hei,wid,3))[:,:,2].astype(np.float32)
        
        data_store['input'].append(temp)
        
        #Open ground-truth image.
        img =  Image.open(file_path+n+'dots.png').getdata()
        data_store['gt'].append(np.array(img).reshape((hei,wid))[:,:].astype(np.float64))
        
        #Filter ground-truth image to produce density kernel representation
        data_store['dense'].append(ndimage.filters.gaussian_filter(data_store['gt'][i],sigma,mode='constant'))


    train = []
    gtdata = []

    shuf_train_images, shuf_test_images = return_shuffled_im(train_size,test_size,input_seq)
    
    X_trainf = []
    Y_trainf = []
    X_testf = []
    Y_testf = []

    for i in shuf_train_images:
        X_trainf.append(data_store['input'][i])
        Y_trainf.append(data_store['dense'][i])
    for i in shuf_test_images:
        X_testf.append(data_store['input'][i])
        Y_testf.append(data_store['dense'][i])

    #X_trainf, X_testf, Y_trainf, Y_testf = train_test_split(data_store['input'],  data_store['dense'], train_size = train_size,test_size=18)
    train_cut, train_gtdata_cut, images_per_image = split_the_images(X_trainf, Y_trainf,in_hei,in_wid,mag)
    test_cut, test_gtdata_cut, images_per_image = split_the_images(X_testf, Y_testf,in_hei,in_wid,mag)
    

    X_train = np.array(train_cut)
    Y_train = np.array(train_gtdata_cut)  
    X_test = np.array(test_cut)
    Y_test = np.array(test_gtdata_cut)


    #Stores history of paramaters.
    hist = keras.callbacks.History()


    # combine generators into one which yields image and masks
    #train_generator = zip(image_generator, mask_generator)
    height = X_train.shape[2]
    width = X_train.shape[3]
    model = get_unet(height, width)

    X_train = np.swapaxes(X_train,1,3)
    X_train = np.swapaxes(X_train,2,1)
    Y_train = np.swapaxes(Y_train,1,3)
    Y_train = np.swapaxes(Y_train,2,1)
    X_test = np.swapaxes(X_test,1,3)
    X_test = np.swapaxes(X_test,2,1)
    Y_test = np.swapaxes(Y_test,1,3)
    Y_test = np.swapaxes(Y_test,2,1)
   
    
    print 'fitting model',X_train.shape,np.max(X_train)
    checkpoint = ModelCheckpoint(filepath+".hdf5",  monitor='loss', verbose=1, save_best_only=save_best_only, mode='min')


    
    datagen = ImageDataGenerator(
        featurewise_center = False,  # set input mean to 0 over the dataset
        samplewise_center = False,  # set each sample mean to 0
        featurewise_std_normalization = False,  # divide inputs by std of the dataset
        samplewise_std_normalization = False,  # divide each input by its std
        zca_whitening = False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range = 0.3,  # randomly shift images horizontally (fraction of total width)
        height_shift_range = 0.3,  # randomly shift images vertically (fraction of total height)
        zoom_range = 0.3,
        shear_range = 0.,
        horizontal_flip = True,  # randomly flip images
        vertical_flip = True,
        fill_mode = 'constant',
        dim_ordering = 'tf')  # randomly flip images


    change_lr = LearningRateScheduler(step_decay)

    callbacks_list = [checkpoint, change_lr]



    hist = model.fit_generator(datagen.flow(X_train,Y_train,batch_size = batch_size), samples_per_epoch = samples_per_epoch, nb_epoch=nb_epoch, callbacks=callbacks_list, verbose=True, validation_data=(X_test, Y_test))
    
    #Store the paramters of the fit, along with the model and data preprocessing.
    hist.history['parameters'] = {}
    hist.history['parameters']['batch_size'] = batch_size
    hist.history['parameters']['nb_epoch'] = nb_epoch
    hist.history['parameters']['in_hei'] = in_hei
    hist.history['parameters']['in_wid'] = in_wid
    hist.history['parameters']['mag'] = mag
    hist.history['parameters']['sigma'] = sigma
    hist.history['parameters']['train_size'] = train_size
    hist.history['parameters']['learning_rate'] = learning_rate
    hist.history['parameters']['shuf_train_images'] = shuf_train_images
    hist.history['parameters']['shuf_test_images'] = shuf_test_images
    hist.history['parameters']['loss'] = loss
    hist.history['parameters']['save_best_only'] = save_best_only
    pickle.dump(hist.history,open(filepath+'.his',"wb"))
# Out:
# fitting model (1488, 128, 128, 1) 20.385
# Learning rate for epoch 1 is 0.001.
# Epoch 1/100
# 8/9 [=========================>....] - ETA: 7s - loss: 1.1195 Epoch 00000: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 502s - loss: 1.0884 - val_loss: 0.9660
# Learning rate for epoch 2 is 0.001.
# Epoch 2/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.7716 Epoch 00001: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 161s - loss: 0.7539 - val_loss: 0.9707
# Learning rate for epoch 3 is 0.001.
# Epoch 3/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6482 Epoch 00002: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 165s - loss: 0.6139 - val_loss: 0.9693
# Learning rate for epoch 4 is 0.001.
# Epoch 4/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5879 Epoch 00003: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 169s - loss: 0.5754 - val_loss: 0.9738
# Learning rate for epoch 5 is 0.001.
# Epoch 5/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6882 Epoch 00004: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 166s - loss: 0.7042 - val_loss: 0.9742
# Learning rate for epoch 6 is 0.001.
# Epoch 6/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6860 Epoch 00005: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 166s - loss: 0.7099 - val_loss: 0.9776
# Learning rate for epoch 7 is 0.001.
# Epoch 7/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.7112 Epoch 00006: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 168s - loss: 0.6799 - val_loss: 0.9810
# Learning rate for epoch 8 is 0.001.
# Epoch 8/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.
100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5571 Epoch 00052: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5488 - val_loss: 0.7929
# Learning rate for epoch 54 is 1e-06.
# Epoch 54/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5723 Epoch 00053: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 160s - loss: 0.6008 - val_loss: 0.7912
# Learning rate for epoch 55 is 1e-06.
# Epoch 55/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4527 Epoch 00054: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.4532 - val_loss: 0.7896
# Learning rate for epoch 56 is 1e-06.
# Epoch 56/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.4590 Epoch 00055: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.4675 - val_loss: 0.7876
# Learning rate for epoch 57 is 1e-06.
# Epoch 57/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6035 Epoch 00056: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.6248 - val_loss: 0.7869
# Learning rate for epoch 58 is 1e-06.
# Epoch 58/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5677 Epoch 00057: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5714 - val_loss: 0.7859
# Learning rate for epoch 59 is 1e-06.
# Epoch 59/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6057 Epoch 00058: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5788 - val_loss: 0.7849
# Learning rate for epoch 60 is 1e-06.
# Epoch 60/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5667 Epoch 00059: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5499 - val_loss: 0.7838
# Learning rate for epoch 61 is 1e-06.
# Epoch 61/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5949 Epoch 00060: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5625 - val_loss: 0.7831
# Learning rate for epoch 62 is 1e-06.
# Epoch 62/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5272 Epoch 00061: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5128 - val_loss: 0.7822
# Learning rate for epoch 63 is 1e-06.
# Epoch 63/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5944 Epoch 00062: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5875 - val_loss: 0.7817
# Learning rate for epoch 64 is 1e-06.
# Epoch 64/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5661 Epoch 00063: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5733 - val_loss: 0.7814
# Learning rate for epoch 65 is 1e-06.
# Epoch 65/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5361 Epoch 00064: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5023 - val_loss: 0.7810
# Learning rate for epoch 66 is 1e-06.
# Epoch 66/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5016 Epoch 00065: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.4906 - val_loss: 0.7805
# Learning rate for epoch 67 is 1e-06.
# Epoch 67/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5398 Epoch 00066: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5556 - val_loss: 0.7803
# Learning rate for epoch 68 is 1e-06.
# Epoch 68/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5951 Epoch 00067: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.6055 - val_loss: 0.7799
# Learning rate for epoch 69 is 1e-06.
# Epoch 69/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5633 Epoch 00068: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 159s - loss: 0.5413 - val_loss: 0.7796
# Learning rate for epoch 70 is 1e-06.
# Epoch 70/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5780 Epoch 00069: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5624 - val_loss: 0.7793
# Learning rate for epoch 71 is 1e-06.
# Epoch 71/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5988 Epoch 00070: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.6185 - val_loss: 0.7792
# Learning rate for epoch 72 is 1e-06.
# Epoch 72/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4873 Epoch 00071: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.4813 - val_loss: 0.7790
# Learning rate for epoch 73 is 1e-06.
# Epoch 73/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5723 Epoch 00072: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5617 - val_loss: 0.7790
# Learning rate for epoch 74 is 1e-06.
# Epoch 74/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5397 Epoch 00073: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5352 - val_loss: 0.7789
# Learning rate for epoch 75 is 1e-06.
# Epoch 75/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5691 Epoch 00074: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5722 - val_loss: 0.7788
# Learning rate for epoch 76 is 1e-06.
# Epoch 76/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4872 Epoch 00075: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.4694 - val_loss: 0.7785
# Learning rate for epoch 77 is 1e-06.
# Epoch 77/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4971 Epoch 00076: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5270 - val_loss: 0.7784
# Learning rate for epoch 78 is 1e-06.
# Epoch 78/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6336 Epoch 00077: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.6255 - val_loss: 0.7785
# Learning rate for epoch 79 is 1e-06.
# Epoch 79/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5203 Epoch 00078: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5300 - val_loss: 0.7783
# Learning rate for epoch 80 is 1e-06.
# Epoch 80/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6167 Epoch 00079: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5854 - val_loss: 0.7782
# Learning rate for epoch 81 is 1e-06.
# Epoch 81/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5973 Epoch 00080: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5728 - val_loss: 0.7781
# Learning rate for epoch 82 is 1e-06.
# Epoch 82/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5555 Epoch 00081: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5440 - val_loss: 0.7780
# Learning rate for epoch 83 is 1e-06.
# Epoch 83/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4837 Epoch 00082: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.4943 - val_loss: 0.7779
# Learning rate for epoch 84 is 1e-06.
# Epoch 84/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5475 Epoch 00083: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5326 - val_loss: 0.7777
# Learning rate for epoch 85 is 1e-06.
# Epoch 85/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5479 Epoch 00084: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5637 - val_loss: 0.7776
# Learning rate for epoch 86 is 1e-06.
# Epoch 86/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4551 Epoch 00085: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.4564 - val_loss: 0.7776
# Learning rate for epoch 87 is 1e-06.
# Epoch 87/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4656 Epoch 00086: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.4824 - val_loss: 0.7774
# Learning rate for epoch 88 is 1e-06.
# Epoch 88/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6464 Epoch 00087: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.6521 - val_loss: 0.7777
# Learning rate for epoch 89 is 1e-06.
# Epoch 89/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5815 Epoch 00088: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5822 - val_loss: 0.7777
# Learning rate for epoch 90 is 1e-06.
# Epoch 90/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5847 Epoch 00089: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5544 - val_loss: 0.7776
# Learning rate for epoch 91 is 1e-06.
# Epoch 91/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5439 Epoch 00090: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5283 - val_loss: 0.7774
# Learning rate for epoch 92 is 1e-06.
# Epoch 92/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.5978 Epoch 00091: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.5667 - val_loss: 0.7775
# Learning rate for epoch 93 is 1e-06.
# Epoch 93/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4746 Epoch 00092: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.4708 - val_loss: 0.7772
# Learning rate for epoch 94 is 1e-06.
# Epoch 94/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5616 Epoch 00093: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5633 - val_loss: 0.7773
# Learning rate for epoch 95 is 1e-06.
# Epoch 95/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5735 Epoch 00094: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5783 - val_loss: 0.7773
# Learning rate for epoch 96 is 1e-06.
# Epoch 96/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5073 Epoch 00095: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 158s - loss: 0.4774 - val_loss: 0.7771
# Learning rate for epoch 97 is 1e-06.
# Epoch 97/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.4781 Epoch 00096: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.4687 - val_loss: 0.7770
# Learning rate for epoch 98 is 1e-06.
# Epoch 98/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5332 Epoch 00097: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5547 - val_loss: 0.7772
# Learning rate for epoch 99 is 1e-06.
# Epoch 99/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5902 Epoch 00098: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.6103 - val_loss: 0.7773
# Learning rate for epoch 100 is 1e-06.
# Epoch 100/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6118 Epoch 00099: saving model to saved_models/keras_tf_exp_sdataset02s2_model_0.hdf5
# 9/9 [==============================] - 157s - loss: 0.5876 - val_loss: 0.7773
# fitting model (1488, 128, 128, 1) 16.8014
# Learning rate for epoch 1 is 0.001.
# Epoch 1/100
# 8/9 [=========================>....] - ETA: 7s - loss: 1.2712 Epoch 00000: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 159s - loss: 1.2425 - val_loss: 0.9390
# Learning rate for epoch 2 is 0.001.
# Epoch 2/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8475 Epoch 00001: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 155s - loss: 0.8888 - val_loss: 0.9438
# Learning rate for epoch 3 is 0.001.
# Epoch 3/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8944 Epoch 00002: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.8714 - val_loss: 0.9406
# Learning rate for epoch 4 is 0.001.
# Epoch 4/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8322 Epoch 00003: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.8055 - val_loss: 0.9422
# Learning rate for epoch 5 is 0.001.
# Epoch 5/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8123 Epoch 00004: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.8314 - val_loss: 0.9445
# Learning rate for epoch 6 is 0.001.
# Epoch 6/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8587 Epoch 00005: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.8687 - val_loss: 0.9452
# Learning rate for epoch 7 is 0.001.
# Epoch 7/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8443 Epoch 00006: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.8284 - val_loss: 0.9476
# Learning rate for epoch 8 is 0.001.
# Epoch 8/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7710 Epoch 00007: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7852 - val_loss: 0.9505
# Learning rate for epoch 9 is 0.001.
# Epoch 9/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.8596 Epoch 00008: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.8721 - val_loss: 0.9519
# Learning rate for epoch 10 is 0.001.
# Epoch 10/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6088 Epoch 00009: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6371 - val_loss: 0.9555
# Learning rate for epoch 11 is 0.001.
# Epoch 11/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6966 Epoch 00010: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7200 - val_loss: 0.9548
# Learning rate for epoch 12 is 0.001.
# Epoch 12/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7216 Epoch 00011: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7026 - val_loss: 0.9535
# Learning rate for epoch 13 is 0.001.
# Epoch 13/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7975 Epoch 00012: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.8055 - val_loss: 0.9509
# Learning rate for epoch 14 is 0.001.
# Epoch 14/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6497 Epoch 00013: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6689 - val_loss: 0.9502
# Learning rate for epoch 15 is 0.001.
# Epoch 15/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6823 Epoch 00014: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6918 - val_loss: 0.9487
# Learning rate for epoch 16 is 0.001.
# Epoch 16/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7432 Epoch 00015: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7585 - val_loss: 0.9458
# Learning rate for epoch 17 is 0.0001.
# Epoch 17/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7644 Epoch 00016: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7521 - val_loss: 0.9417
# Learning rate for epoch 18 is 0.0001.
# Epoch 18/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7236 Epoch 00017: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6909 - val_loss: 0.9380
# Learning rate for epoch 19 is 0.0001.
# Epoch 19/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7155 Epoch 00018: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6946 - val_loss: 0.9341
# Learning rate for epoch 20 is 0.0001.
# Epoch 20/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5648 Epoch 00019: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.5732 - val_loss: 0.9300
# Learning rate for epoch 21 is 0.0001.
# Epoch 21/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7034 Epoch 00020: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7024 - val_loss: 0.9254
# Learning rate for epoch 22 is 0.0001.
# Epoch 22/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6730 Epoch 00021: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6576 - val_loss: 0.9189
# Learning rate for epoch 23 is 0.0001.
# Epoch 23/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7583 Epoch 00022: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7354 - val_loss: 0.9107
# Learning rate for epoch 24 is 0.0001.
# Epoch 24/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7045 Epoch 00023: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6799 - val_loss: 0.9018
# Learning rate for epoch 25 is 0.0001.
# Epoch 25/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7055 Epoch 00024: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6845 - val_loss: 0.8913
# Learning rate for epoch 26 is 0.0001.
# Epoch 26/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6632 Epoch 00025: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 158s - loss: 0.6745 - val_loss: 0.8798
# Learning rate for epoch 27 is 0.0001.
# Epoch 27/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.7526 Epoch 00026: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 158s - loss: 0.7396 - val_loss: 0.8677
# Learning rate for epoch 28 is 0.0001.
# Epoch 28/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7039 Epoch 00027: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7347 - val_loss: 0.8553
# Learning rate for epoch 29 is 0.0001.
# Epoch 29/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5917 Epoch 00028: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6344 - val_loss: 0.8422
# Learning rate for epoch 30 is 0.0001.
# Epoch 30/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6768 Epoch 00029: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6444 - val_loss: 0.8298
# Learning rate for epoch 31 is 0.0001.
# Epoch 31/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6665 Epoch 00030: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6341 - val_loss: 0.8187
# Learning rate for epoch 32 is 0.0001.
# Epoch 32/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6771 Epoch 00031: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6750 - val_loss: 0.8083
# Learning rate for epoch 33 is 1e-05.
# Epoch 33/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6271 Epoch 00032: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6707 - val_loss: 0.7972
# Learning rate for epoch 34 is 1e-05.
# Epoch 34/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6858 Epoch 00033: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6668 - val_loss: 0.7861
# Learning rate for epoch 35 is 1e-05.
# Epoch 35/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6670 Epoch 00034: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6484 - val_loss: 0.7760
# Learning rate for epoch 36 is 1e-05.
# Epoch 36/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6508 Epoch 00035: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6614 - val_loss: 0.7665
# Learning rate for epoch 37 is 1e-05.
# Epoch 37/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6953 Epoch 00036: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7077 - val_loss: 0.7583
# Learning rate for epoch 38 is 1e-05.
# Epoch 38/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7099 Epoch 00037: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6981 - val_loss: 0.7505
# Learning rate for epoch 39 is 1e-05.
# Epoch 39/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6747 Epoch 00038: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6876 - val_loss: 0.7441
# Learning rate for epoch 40 is 1e-05.
# Epoch 40/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7629 Epoch 00039: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7537 - val_loss: 0.7383
# Learning rate for epoch 41 is 1e-05.
# Epoch 41/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5161 Epoch 00040: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.5556 - val_loss: 0.7323
# Learning rate for epoch 42 is 1e-05.
# Epoch 42/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6120 Epoch 00041: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6248 - val_loss: 0.7275
# Learning rate for epoch 43 is 1e-05.
# Epoch 43/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6234 Epoch 00042: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6067 - val_loss: 0.7232
# Learning rate for epoch 44 is 1e-05.
# Epoch 44/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7089 Epoch 00043: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7148 - val_loss: 0.7199
# Learning rate for epoch 45 is 1e-05.
# Epoch 45/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6005 Epoch 00044: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6044 - val_loss: 0.7163
# Learning rate for epoch 46 is 1e-05.
# Epoch 46/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6233 Epoch 00045: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6557 - val_loss: 0.7138
# Learning rate for epoch 47 is 1e-05.
# Epoch 47/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7296 Epoch 00046: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7312 - val_loss: 0.7118
# Learning rate for epoch 48 is 1e-05.
# Epoch 48/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7146 Epoch 00047: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7044 - val_loss: 0.7099
# Learning rate for epoch 49 is 1e-06.
# Epoch 49/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7132 Epoch 00048: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6927 - val_loss: 0.7083
# Learning rate for epoch 50 is 1e-06.
# Epoch 50/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6733 Epoch 00049: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6619 - val_loss: 0.7069
# Learning rate for epoch 51 is 1e-06.
# Epoch 51/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5650 Epoch 00050: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.5639 - val_loss: 0.7057
# Learning rate for epoch 52 is 1e-06.
# Epoch 52/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6603 Epoch 00051: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6633 - val_loss: 0.7048
# Learning rate for epoch 53 is 1e-06.
# Epoch 53/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6880 Epoch 00052: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6607 - val_loss: 0.7042
# Learning rate for epoch 54 is 1e-06.
# Epoch 54/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6789 Epoch 00053: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6628 - val_loss: 0.7037
# Learning rate for epoch 55 is 1e-06.
# Epoch 55/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6566 Epoch 00054: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6249 - val_loss: 0.7032
# Learning rate for epoch 56 is 1e-06.
# Epoch 56/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6825 Epoch 00055: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6668 - val_loss: 0.7029
# Learning rate for epoch 57 is 1e-06.
# Epoch 57/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6573 Epoch 00056: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6718 - val_loss: 0.7026
# Learning rate for epoch 58 is 1e-06.
# Epoch 58/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7244 Epoch 00057: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7069 - val_loss: 0.7024
# Learning rate for epoch 59 is 1e-06.
# Epoch 59/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7043 Epoch 00058: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7368 - val_loss: 0.7022
# Learning rate for epoch 60 is 1e-06.
# Epoch 60/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5931 Epoch 00059: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6338 - val_loss: 0.7020
# Learning rate for epoch 61 is 1e-06.
# Epoch 61/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6567 Epoch 00060: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6302 - val_loss: 0.7019
# Learning rate for epoch 62 is 1e-06.
# Epoch 62/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6595 Epoch 00061: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6289 - val_loss: 0.7018
# Learning rate for epoch 63 is 1e-06.
# Epoch 63/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6679 Epoch 00062: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6828 - val_loss: 0.7017
# Learning rate for epoch 64 is 1e-06.
# Epoch 64/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5882 Epoch 00063: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6264 - val_loss: 0.7017
# Learning rate for epoch 65 is 1e-06.
# Epoch 65/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6830 Epoch 00064: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6683 - val_loss: 0.7017
# Learning rate for epoch 66 is 1e-06.
# Epoch 66/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6710 Epoch 00065: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6515 - val_loss: 0.7017
# Learning rate for epoch 67 is 1e-06.
# Epoch 67/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6568 Epoch 00066: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.6704 - val_loss: 0.7017
# Learning rate for epoch 68 is 1e-06.
# Epoch 68/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7027 Epoch 00067: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7043 - val_loss: 0.7017
# Learning rate for epoch 69 is 1e-06.
# Epoch 69/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7157 Epoch 00068: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 157s - loss: 0.7104 - val_loss: 0.7017
# Learning rate for epoch 70 is 1e-06.
# Epoch 70/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6962 Epoch 00069: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6920 - val_loss: 0.7016
# Learning rate for epoch 71 is 1e-06.
# Epoch 71/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.7548 Epoch 00070: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.7567 - val_loss: 0.7016
# Learning rate for epoch 72 is 1e-06.
# Epoch 72/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5312 Epoch 00071: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.5605 - val_loss: 0.7017
# Learning rate for epoch 73 is 1e-06.
# Epoch 73/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6554 Epoch 00072: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6629 - val_loss: 0.7017
# Learning rate for epoch 74 is 1e-06.
# Epoch 74/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6346 Epoch 00073: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6167 - val_loss: 0.7018
# Learning rate for epoch 75 is 1e-06.
# Epoch 75/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6872 Epoch 00074: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6893 - val_loss: 0.7018
# Learning rate for epoch 76 is 1e-06.
# Epoch 76/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5972 Epoch 00075: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# 9/9 [==============================] - 156s - loss: 0.6045 - val_loss: 0.7018
# Learning rate for epoch 77 is 1e-06.
# Epoch 77/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6263 Epoch 00076: saving model to saved_models/keras_tf_exp_sdataset02s2_model_1.hdf5
# ...
# Epoch 45/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5716 Epoch 00044: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 154s - loss: 0.5756 - val_loss: 0.7889
# Learning rate for epoch 46 is 1e-05.
# Epoch 46/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5055 Epoch 00045: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 155s - loss: 0.5376 - val_loss: 0.7859
# Learning rate for epoch 47 is 1e-05.
# Epoch 47/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5653 Epoch 00046: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 154s - loss: 0.6256 - val_loss: 0.7836
# Learning rate for epoch 48 is 1e-05.
# Epoch 48/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6260 Epoch 00047: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 155s - loss: 0.6434 - val_loss: 0.7819
# Learning rate for epoch 49 is 1e-06.
# Epoch 49/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5990 Epoch 00048: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 155s - loss: 0.5877 - val_loss: 0.7795
# Learning rate for epoch 50 is 1e-06.
# Epoch 50/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5919 Epoch 00049: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 155s - loss: 0.5998 - val_loss: 0.7775
# Learning rate for epoch 51 is 1e-06.
# Epoch 51/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.5451 Epoch 00050: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 156s - loss: 0.5569 - val_loss: 0.7755
# Learning rate for epoch 52 is 1e-06.
# Epoch 52/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.6228 Epoch 00051: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 163s - loss: 0.6098 - val_loss: 0.7740
# Learning rate for epoch 53 is 1e-06.
# Epoch 53/100
# 8/9 [=========================>....] - ETA: 8s - loss: 0.
saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 158s - loss: 0.6522 - val_loss: 0.7622
# Learning rate for epoch 100 is 1e-06.
# Epoch 100/100
# 8/9 [=========================>....] - ETA: 7s - loss: 0.6175 Epoch 00099: saving model to saved_models/keras_tf_exp_sdataset02s2_model_4.hdf5
# 9/9 [==============================] - 156s - loss: 0.6003 - val_loss: 0.7622
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:128: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:128: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., verbose=True, validation_data=(array([[[..., steps_per_epoch=9, epochs=100, callbacks=[<keras.ca...)`

# %% [markdown]
# # Code for making predictions

# %%
##Load in the paramters.

model_path ='saved_models'
experiment = 'keras_tf_exp_sdataset02s2_model_'

imported_pickle = pickle.load(open(model_path+'/'+experiment+'0.his',"rb"))

parameters = imported_pickle['parameters']
file_path = 'dataset02/'
data_store = {}
data_store['input'] = []
data_store['gt'] = []
data_store['dense'] = []
train = []
gtdata = []
in_hei = parameters['in_hei']
in_wid = parameters['in_wid']
mag = parameters['mag']
learning_rate = parameters['learning_rate']
#get_unet = parameters['unet']
loss = parameters['loss'] 
save_best_only = parameters['save_best_only']



#optimizer_fn = parameters['optimizer']
#model_fn = parameters['model']
loss = 'mse'
sigma = parameters['sigma']
#metrics = [accuracy_custom,accuracy_custom2]
num_of_train = 19
test_size = 18

   
#optimizer = optimizer_fn(lr=learning_rate,momentum=0.9,decay=0.1)

##Load the images for testing.
for i in range(0,num_of_train):
    n = str(i+80).zfill(3)
    
    #Open intensity image.
    img = Image.open(file_path+n+'cells.png').getdata()
    wid,hei = img.size
    temp = np.array(img).reshape((hei,wid,3))[:,:,2].astype(np.float32)
    
    data_store['input'].append(temp)
    
    #Open ground-truth image.
    img =  Image.open(file_path+n+'dots.png').getdata()
    data_store['gt'].append(np.array(img).reshape((hei,wid))[:,:].astype(np.float64))
    
    #Filter ground-truth image to produce density kernel representation
    data_store['dense'].append(ndimage.filters.gaussian_filter(data_store['gt'][i],sigma,mode='constant'))




X_trainf, X_testf, Y_trainf, Y_testf = train_test_split(data_store['input'],  data_store['dense'], train_size =1,test_size=test_size)

test_cut, test_gtdata_cut,images_per_image = split_the_images(X_testf, Y_testf,in_hei,in_wid,mag)

X_test = np.array(test_cut)
Y_test = np.array(test_gtdata_cut)  



X_test = np.swapaxes(X_test,1,3)
X_test = np.swapaxes(X_test,2,1)

for vt in range(0,5):
    filename=model_path+"/"+experiment+""+str(vt)+".hdf5"
    # load json and create model


        


    # load weights into new model
    loaded_model = load_model(filename)
    print("Loaded model from disk")
    imported_pickle = pickle.load(open(model_path+'/'+experiment+""+str(vt)+'.his',"rb"))

    f = open(model_path+'/'+experiment+str(vt)+'out.txt', 'w+')

    loss_print = imported_pickle['loss']
    val_loss_print = imported_pickle['val_loss']
    f.write('loss_pt\tval_pt\n')
    for loss_pt, val_pt in zip(loss_print, val_loss_print):
            f.write(str(loss_pt)+'\t'+str(val_pt)+'\n')
    f.close()
    #print 'final train loss', imported_pickle['loss'][-1]
    #print 'final train accuracy', imported_pickle['accuracy_custom'][-1]
     
    # evaluate loaded model on test data
    #loaded_model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])
    imgs_mask_test = loaded_model.predict(X_test, verbose=1)
    #Switches format for tensor flow.
    imgs_mask_test = np.swapaxes(imgs_mask_test,2,1)
    imgs_mask_test = np.swapaxes(imgs_mask_test,1,3)
    data_store['output'] = []
    c =0

    null,f_hei, f_wid = imgs_mask_test[0].shape
    
    #reconstruct the images.

    while c < (imgs_mask_test.__len__()-images_per_image)+1:
        out = np.zeros((hei,wid))
        rows = 0
        for rst in range(0,hei,in_hei):
            rows +=1
            cols = 0
            d = np.floor(float(c)/float(images_per_image))
            for cst in range(0,wid,in_wid):
                cols +=1
                img = imgs_mask_test[c]
                c +=1
                top = bottom = left = right = 16
                ren = rst + in_hei
                cen = cst + in_wid
                if ren> hei:

                    top = top + (ren-hei)
                    ren = hei
                if cen> wid:


                    right = right + (cen-wid)
                    cen = wid

                out[rst:ren,cst:cen] = img[0,bottom:-top,left:-right]
        
        data_store['output'].append(out)
        
    


    #Output of performance metrics


    pef = []
    trk = []
    abs_err = []
    inpu_arr = []
    pred_arr = []
    perc_arr = []

    print data_store['output'].__len__()
    print test_size
    #figsize(12,12)
    for idx in range(0,test_size):
        #figure()
        inpu_img = Y_testf[idx]
        pred_img = data_store['output'][idx]
        n = str(idx)
        b = n.zfill(3)
        pickle.dump( inpu_img, open( "out_imgs/inpu_img"+b+".p", "wb" ) )
        pickle.dump( pred_img, open( "out_imgs/pred_img"+b+".p", "wb" ) )
        #subplot(1,2,1)
        #imshow(inpu_img)
        #subplot(1,2,2)
        #imshow(pred_img)
        inpu_sum = np.sum(inpu_img)/255.0
        pred_sum = np.sum(pred_img)/255.0
        #print 'img',idx
        #print inpu_sum
        #print pred_sum
        #print abs(inpu_sum-pred_sum)
        inpu_arr.append(inpu_sum)
        pred_arr.append(pred_sum)
        abs_err.append(abs(inpu_sum-pred_sum))
        perc_arr.append((1-(abs(inpu_sum-pred_sum)/pred_sum))*100)
        #print np.round((1-(abs(inpu_sum-pred_sum)/pred_sum))*100,0),'%'
    print np.average(abs_err)
    print np.average(inpu_arr)
    print 'average pred',np.average(pred_arr)
    print 'average perc',np.average(perc_arr)
    imported_pickle['pred_arr'] = pred_arr
    imported_pickle['perc_arr'] = perc_arr
    imported_pickle['abs_err'] = pred_arr
    imported_pickle['inpu_arr'] = perc_arr
    #imported_pickle['img_inpu_arr'] = Y_testf
    #imported_pickle['img_pred_arr'] = data_store['output']

    pickle.dump(imported_pickle,open(model_path+'/'+experiment+""+str(vt)+'.his',"w"))
# Out:
# Loaded model from disk
# 432/432 [==============================] - 86s
# 18
# 18
# 75.3691264676
# 253.427469673
# average pred 195.517077439
# average perc 61.5872901215
# Loaded model from disk
# 432/432 [==============================] - 93s
# 18
# 18
# 46.6449747582
# 253.427469673
# average pred 237.714488862
# average perc 76.7225917836
# Loaded model from disk
# 432/432 [==============================] - 98s
# 18
# 18
# 46.7965300023
# 253.427469673
# average pred 229.263221885
# average perc 76.8773015698
# Loaded model from disk
# 432/432 [==============================] - 100s
# 18
# 18
# 45.5731298676
# 253.427469673
# average pred 233.043273603
# average perc 77.1632131545
# Loaded model from disk
# 432/432 [==============================] - 97s
# 18
# 18
# 61.171888416
# 253.427469673
# average pred 222.580019421
# average perc 70.7777519715
